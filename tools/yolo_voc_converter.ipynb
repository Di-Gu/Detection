# %%
# Script to convert yolo annotations to voc format

# Sample format
# <annotation>
#     <folder>data</folder>
#     <filename>example.jpg</filename>
#     <path>C:\Users\DiPad\Desktop\try\data\example.jpg</path>
#     <size>
#         <width>1200</width>
#         <height>800</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#         <name>head</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>549</xmin>
#             <ymin>251</ymin>
#             <xmax>625</xmax>
#             <ymax>335</ymax>
#         </bndbox>
#     </object>
# <annotation>

import os
# import xml.etree.ElementTree as ET
from lxml import etree as ET
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np

want = "train"

ANNOTATIONS_DIR_PREFIX = want

DESTINATION_DIR = want

CLASS_MAPPING = {
    '0':'dolphin',
    '1':'fish',
    '2':'trutle',
    '3':'jellyfish',
    '4':'starfish',
    '5':'swordfish'
    # Add classes if needed.
}


def create_root(file_prefix, width, height):
    root = ET.Element("annotation")
    ############################################
    # make sure this is the folder and path for images
    ET.SubElement(root, "folder").text = "val"
    ET.SubElement(root, "filename").text = "{}.jpg".format(file_prefix)
    x = os.getcwd()
    ET.SubElement(root,"path").text = x+"/"+want+"/{}.jpg".format(file_prefix)
    ############################################
    size = ET.SubElement(root, "size")
    ET.SubElement(size, "width").text = str(width)
    ET.SubElement(size, "height").text = str(height)
    ET.SubElement(size, "depth").text = "3"
    return root


def create_object_annotation(root, voc_labels):
    for voc_label in voc_labels:
        obj = ET.SubElement(root, "object")
        ET.SubElement(obj, "name").text = voc_label[0]
        ET.SubElement(obj, "pose").text = "Unspecified"
        ET.SubElement(obj, "truncated").text = str(0)
        ET.SubElement(obj, "difficult").text = str(0)
        bbox = ET.SubElement(obj, "bndbox")
        ET.SubElement(bbox, "xmin").text = str(voc_label[1])
        ET.SubElement(bbox, "ymin").text = str(voc_label[2])
        ET.SubElement(bbox, "xmax").text = str(voc_label[3])
        ET.SubElement(bbox, "ymax").text = str(voc_label[4])
    return root


def create_file(file_prefix, width, height, voc_labels):
    root = create_root(file_prefix, width, height)
    root = create_object_annotation(root, voc_labels)
    tree = ET.ElementTree(root)
    tree.write("{}/{}.xml".format(DESTINATION_DIR, file_prefix),pretty_print=True)


def read_file(file_path):
    print(file_path)
    file_prefix = file_path.split(".txt")[0]
#     print(file_prefix)
    image_file_name = "{}.jpg".format(file_prefix)
#     print(image_file_name)
    img = Image.open("{}/{}".format(want, image_file_name))
#     imshow(np.asarray(img))
    w, h = img.size
#     print(w,h)
    with open(want+'/'+file_path, 'r') as file:
        lines = file.readlines()
        voc_labels = []
        for line in lines:
            voc = []
            line = line.strip()
            data = line.split()
            voc.append(CLASS_MAPPING.get(data[0]))
            bbox_width = float(data[3]) * w
            bbox_height = float(data[4]) * h
            center_x = float(data[1]) * w
            center_y = float(data[2]) * h
            voc.append(round(center_x - (bbox_width / 2)))
            voc.append(round(center_y - (bbox_height / 2)))
            voc.append(round(center_x + (bbox_width / 2)))
            voc.append(round(center_y + (bbox_height / 2)))
            voc_labels.append(voc)
        create_file(file_prefix, w, h, voc_labels)
    print("Processing complete for file: {}".format(file_path))


def start(dir_name):
    if not os.path.exists(DESTINATION_DIR):
        os.makedirs(DESTINATION_DIR)
    for filename in os.listdir(ANNOTATIONS_DIR_PREFIX):
        if filename.endswith('txt'):
            read_file(filename)
        else:
            print("Skipping file: {}".format(filename))


if __name__ == "__main__":
    start(want)
# Out:
# Skipping file: dolphin_53.xml
# Skipping file: starfish_108.jpg
# jellyfish_45.txt
# Processing complete for file: jellyfish_45.txt
# Skipping file: starfish_55.jpg
# Skipping file: dolphin_2.xml
# Skipping file: fish_12.jpg
# Skipping file: starfish_74.jpg
# Skipping file: fish_119.xml
# Skipping file: starfish_118.jpg
# Skipping file: turtle_25.xml
# Skipping file: dolphin_12.jpg
# Skipping file: dolphin_14.jpg
# Skipping file: starfish_80.jpg
# Skipping file: fish_19.jpg
# Skipping file: fish_21.xml
# Skipping file: dolphin_92.xml
# Skipping file: jellyfish_124.jpg
# Skipping file: swordfish_1.xml
# jellyfish_123.txt
# Processing complete for file: jellyfish_123.txt
# Skipping file: dolphin_23.xml
# jellyfish_27.txt
# Processing complete for file: jellyfish_27.txt
# Skipping file: swordfish_0.xml
# Skipping file: fish_6.xml
# Skipping file: jellyfish_123.jpg
# Skipping file: turtle_105.xml
# Skipping file: jellyfish_32.jpg
# Skipping file: fish_43.xml
# Skipping file: turtle_106.jpg
# Skipping file: swordfish_56.jpg
# Skipping file: fish_59.jpg
# Skipping file: dolphin_38.xml
# Skipping file: fish_118.xml
# Skipping file: fish_27.jpg
# Skipping file: turtle_18.xml
# starfish_107.txt
# Processing complete for file: starfish_107.txt
# turtle_22.txt
# Processing complete for file: turtle_22.txt
# Skipping file: dolphin_58.xml
# Skipping file: dolphin_28.jpg
# Skipping file: fish_2.jpg
# Skipping file: dolphin_67.xml
# Skipping file: dolphin_66.jpg
# Skipping file: starfish_125.xml
# jellyfish_12.txt
# Processing complete for file: jellyfish_12.txt
# Skipping file: dolphin_56.jpg
# dolphin_11.txt
# Processing complete for file: dolphin_11.txt
# dolphin_32.txt
# Processing complete for file: dolphin_32.txt
# dolphin_92.txt
# Processing complete for file: dolphin_92.txt
# jellyfish_108.txt
# Processing complete for file: jellyfish_108.txt
# Skipping file: dolphin_32.xml
# turtle_25.txt
# Processing complete for file: turtle_25.txt
# Skipping file: starfish_22.xml
# Skipping file: starfish_119.xml
# turtle_102.txt
# Processing complete for file: turtle_102.txt
# fish_32.txt
# Processing complete for file: fish_32.txt
# dolphin_17.txt
# Processing complete for file: dolphin_17.txt
# Skipping file: turtle_17.jpg
# fish_110.txt
# Processing complete for file: fish_110.txt
# dolphin_45.txt
# Processing complete for file: dolphin_45.txt
# dolphin_66.txt
# Processing complete for file: dolphin_66.txt
# dolphin_3.txt
# Processing complete for file: dolphin_3.txt
# swordfish_63.txt
# Processing complete for file: swordfish_63.txt
# turtle_13.txt
# Processing complete for file: turtle_13.txt
# dolphin_58.txt
# Processing complete for file: dolphin_58.txt
# dolphin_62.txt
# Processing complete for file: dolphin_62.txt
# Skipping file: jellyfish_11.jpg
# Skipping file: turtle_58.jpg
# jellyfish_121.txt
# Processing complete for file: jellyfish_121.txt
# Skipping file: jellyfish_122.jpg
# dolphin_29.txt
# Processing complete for file: dolphin_29.txt
# jellyfish_73.txt
# Processing complete for file: jellyfish_73.txt
# turtle_107.txt
# Processing complete for file: turtle_107.txt
# fish_75.txt
# Processing complete for file: fish_75.txt
# jellyfish_15.txt
# Processing complete for file: jellyfish_15.txt
# jellyfish_122.txt
# Processing complete for file: jellyfish_122.txt
# Skipping file: jellyfish_13.jpg
# Skipping file: starfish_58.xml
# Skipping file: turtle_10.jpg
# fish_2.txt
# Processing complete for file: fish_2.txt
# Skipping file: jellyfish_119.jpg
# Skipping file: starfish_80.xml
# Skipping file: fish_114.xml
# dolphin_10.txt
# Processing complete for file: dolphin_10.txt
# Skipping file: dolphin_40.xml
# swordfish_42.txt
# Processing complete for file: swordfish_42.txt
# swordfish_20.txt
# Processing complete for file: swordfish_20.txt
# Skipping file: swordfish_32.jpg
# dolphin_27.txt
# Processing complete for file: dolphin_27.txt
# Skipping file: starfish_41.jpg
# Skipping file: dolphin_102.jpg
# Skipping file: jellyfish_9.jpg
# fish_51.txt
# Processing complete for file: fish_51.txt
# dolphin_50.txt
# Processing complete for file: dolphin_50.txt
# Skipping file: fish_60.xml
# starfish_58.txt
# Processing complete for file: starfish_58.txt
# Skipping file: starfish_74.xml
# Skipping file: starfish_8.xml
# jellyfish_112.txt
# Processing complete for file: jellyfish_112.txt
# Skipping file: dolphin_59.xml
# jellyfish_105.txt
# Processing complete for file: jellyfish_105.txt
# dolphin_9.txt
# Processing complete for file: dolphin_9.txt
# Skipping file: fish_31.jpg
# Skipping file: fish_39.jpg
# Skipping file: dolphin_4.jpg
# dolphin_104.txt
# Processing complete for file: dolphin_104.txt
# Skipping file: fish_118.jpg
# swordfish_109.txt
# Processing complete for file: swordfish_109.txt
# Skipping file: turtle_105.jpg
# Skipping file: dolphin_34.jpg
# Skipping file: dolphin_70.xml
# Skipping file: dolphin_10.jpg
# Skipping file: swordfish_11.xml
# dolphin_52.txt
# Processing complete for file: dolphin_52.txt
# jellyfish_1.txt
# Processing complete for file: jellyfish_1.txt
# Skipping file: starfish_54.jpg
# dolphin_15.txt
# Processing complete for file: dolphin_15.txt
# turtle_101.txt
# Processing complete for file: turtle_101.txt
# dolphin_39.txt
# Processing complete for file: dolphin_39.txt
# Skipping file: dolphin_24.jpg
# Skipping file: jellyfish_44.jpg
# Skipping file: turtle_33.jpg
# Skipping file: dolphin_61.xml
# Skipping file: fish_116.jpg
# Skipping file: fish_2.xml
# Skipping file: dolphin_101.xml
# Skipping file: swordfish_63.jpg
# Skipping file: starfish_60.jpg
# Skipping file: dolphin_54.xml
# Skipping file: fish_102.jpg
# Skipping file: dolphin_106.jpg
# starfish_109.txt
# Processing complete for file: starfish_109.txt
# Skipping file: turtle_108.jpg
# Skipping file: swordfish_61.jpg
# Skipping file: jellyfish_104.xml
# Skipping file: turtle_1.jpg
# dolphin_53.txt
# Processing complete for file: dolphin_53.txt
# Skipping file: starfish_13.jpg
# Skipping file: dolphin_25.xml
# jellyfish_17.txt
# Processing complete for file: jellyfish_17.txt
# Skipping file: dolphin_99.xml
# Skipping file: turtle_39.jpg
# Skipping file: fish_40.jpg
# turtle_12.txt
# Processing complete for file: turtle_12.txt
# Skipping file: swordfish_28.jpg
# starfish_100.txt
# Processing complete for file: starfish_100.txt
# Skipping file: dolphin_70.jpg
# Skipping file: fish_50.jpg
# Skipping file: fish_59.xml
# starfish_108.txt
# Processing complete for file: starfish_108.txt
# Skipping file: turtle_103.jpg
# Skipping file: starfish_69.xml
# dolphin_24.txt
# Processing complete for file: dolphin_24.txt
# Skipping file: turtle_17.xml
# Skipping file: starfish_119.jpg
# Skipping file: fish_119.jpg
# Skipping file: starfish_121.jpg
# dolphin_12.txt
# Processing complete for file: dolphin_12.txt
# Skipping file: dolphin_57.xml
# dolphin_1.txt
# Processing complete for file: dolphin_1.txt
# starfish_1.txt
# Processing complete for file: starfish_1.txt
# Skipping file: fish_110.jpg
# fish_13.txt
# Processing complete for file: fish_13.txt
# fish_34.txt
# Processing complete for file: fish_34.txt
# starfish_48.txt
# Processing complete for file: starfish_48.txt
# Skipping file: turtle_103.xml
# fish_40.txt
# Processing complete for file: fish_40.txt
# dolphin_68.txt
# Processing complete for file: dolphin_68.txt
# Skipping file: jellyfish_27.xml
# dolphin_34.txt
# Processing complete for file: dolphin_34.txt
# Skipping file: dolphin_3.jpg
# starfish_93.txt
# Processing complete for file: starfish_93.txt
# Skipping file: swordfish_32.xml
# fish_43.txt
# Processing complete for file: fish_43.txt
# Skipping file: fish_111.jpg
# Skipping file: jellyfish_0.xml
# Skipping file: jellyfish_105.jpg
# Skipping file: starfish_109.xml
# Skipping file: dolphin_10.xml
# Skipping file: dolphin_46.jpg
# Skipping file: fish_32.xml
# dolphin_101.txt
# Processing complete for file: dolphin_101.txt
# Skipping file: dolphin_2.jpg
# turtle_93.txt
# Processing complete for file: turtle_93.txt
# swordfish_101.txt
# Processing complete for file: swordfish_101.txt
# swordfish_85.txt
# Processing complete for file: swordfish_85.txt
# Skipping file: fish_117.xml
# Skipping file: swordfish_107.jpg
# Skipping file: swordfish_61.xml
# dolphin_57.txt
# Processing complete for file: dolphin_57.txt
# Skipping file: dolphin_67.jpg
# fish_117.txt
# Processing complete for file: fish_117.txt
# Skipping file: jellyfish_120.jpg
# Skipping file: turtle_100.jpg
# Skipping file: dolphin_12.xml
# Skipping file: starfish_103.xml
# Skipping file: starfish_69.jpg
# Skipping file: swordfish_1.jpg
# jellyfish_46.txt
# Processing complete for file: jellyfish_46.txt
# Skipping file: dolphin_63.xml
# dolphin_105.txt
# Processing complete for file: dolphin_105.txt
# Skipping file: dolphin_59.jpg
# Skipping file: starfish_93.xml
# jellyfish_47.txt
# Processing complete for file: jellyfish_47.txt
# jellyfish_10.txt
# Processing complete for file: jellyfish_10.txt
# Skipping file: dolphin_99.jpg
# fish_59.txt
# Processing complete for file: fish_59.txt
# Skipping file: turtle_42.jpg
# Skipping file: dolphin_107.xml
# Skipping file: dolphin_17.xml
# dolphin_63.txt
# Processing complete for file: dolphin_63.txt
# Skipping file: starfish_107.xml
# Skipping file: dolphin_29.jpg
# turtle_33.txt
# Processing complete for file: turtle_33.txt
# Skipping file: jellyfish_10.xml
# dolphin_38.txt
# Processing complete for file: dolphin_38.txt
# starfish_22.txt
# Processing complete for file: starfish_22.txt
# Skipping file: dolphin_29.xml
# Skipping file: fish_105.xml
# swordfish_28.txt
# Processing complete for file: swordfish_28.txt
# Skipping file: jellyfish_60.jpg
# dolphin_5.txt
# Processing complete for file: dolphin_5.txt
# jellyfish_5.txt
# Processing complete for file: jellyfish_5.txt
# Skipping file: starfish_48.jpg
# Skipping file: fish_75.jpg
# Skipping file: dolphin_46.xml
# starfish_0.txt
# Processing complete for file: starfish_0.txt
# Skipping file: jellyfish_45.jpg
# jellyfish_32.txt
# Processing complete for file: jellyfish_32.txt
# Skipping file: turtle_39.xml
# Skipping file: dolphin_32.jpg
# Skipping file: starfish_59.jpg
# Skipping file: fish_110.xml
# Skipping file: dolphin_52.xml
# Skipping file: jellyfish_45.xml
# Skipping file: fish_105.jpg
# jellyfish_113.txt
# Processing complete for file: jellyfish_113.txt
# fish_27.txt
# Processing complete for file: fish_27.txt
# Skipping file: jellyfish_113.xml
# Skipping file: jellyfish_0.jpg
# Skipping file: starfish_60.xml
# Skipping file: jellyfish_122.xml
# Skipping file: starfish_107.jpg
# dolphin_14.txt
# Processing complete for file: dolphin_14.txt
# dolphin_102.txt
# Processing complete for file: dolphin_102.txt
# Skipping file: starfish_121.xml
# Skipping file: starfish_48.xml
# Skipping file: starfish_0.xml
# dolphin_20.txt
# Processing complete for file: dolphin_20.txt
# Skipping file: fish_102.xml
# Skipping file: fish_10.xml
# Skipping file: turtle_100.xml
# Skipping file: turtle_0.jpg
# Skipping file: jellyfish_112.jpg
# Skipping file: starfish_8.jpg
# swordfish_32.txt
# Processing complete for file: swordfish_32.txt
# Skipping file: fish_94.jpg
# dolphin_44.txt
# Processing complete for file: dolphin_44.txt
# Skipping file: starfish_103.jpg
# Skipping file: swordfish_42.jpg
# Skipping file: dolphin_56.xml
# Skipping file: starfish_1.xml
# Skipping file: fish_13.xml
# Skipping file: turtle_107.jpg
# dolphin_4.txt
# Processing complete for file: dolphin_4.txt
# Skipping file: dolphin_62.jpg
# Skipping file: dolphin_23.jpg
# swordfish_91.txt
# Processing complete for file: swordfish_91.txt
# dolphin_0.txt
# Processing complete for file: dolphin_0.txt
# Skipping file: swordfish_66.jpg
# Skipping file: jellyfish_121.xml
# turtle_0.txt
# Processing complete for file: turtle_0.txt
# Skipping file: jellyfish_103.xml
# Skipping file: fish_51.xml
# Skipping file: jellyfish_105.xml
# Skipping file: dolphin_15.jpg
# Skipping file: starfish_118.xml
# Skipping file: swordfish_52.jpg
# Skipping file: dolphin_27.xml
# jellyfish_124.txt
# Processing complete for file: jellyfish_124.txt
# Skipping file: turtle_12.jpg
# dolphin_70.txt
# Processing complete for file: dolphin_70.txt
# Skipping file: dolphin_108.jpg
# Skipping file: dolphin_14.xml
# Skipping file: turtle_0.xml
# Skipping file: jellyfish_100.jpg
# Skipping file: turtle_42.xml
# Skipping file: turtle_10.xml
# Skipping file: dolphin_34.xml
# Skipping file: starfish_111.xml
# fish_31.txt
# Processing complete for file: fish_31.txt
# Skipping file: dolphin_51.jpg
# Skipping file: dolphin_27.jpg
# Skipping file: turtle_18.jpg
# Skipping file: fish_50.xml
# Skipping file: dolphin_11.xml
# Skipping file: jellyfish_108.xml
# Skipping file: dolphin_44.jpg
# Skipping file: dolphin_20.jpg
# Skipping file: dolphin_50.xml
# Skipping file: swordfish_109.xml
# Skipping file: turtle_93.jpg
# dolphin_106.txt
# Processing complete for file: dolphin_106.txt
# Skipping file: turtle_93.xml
# Skipping file: jellyfish_121.jpg
# dolphin_40.txt
# Processing complete for file: dolphin_40.txt
# Skipping file: dolphin_69.xml
# Skipping file: dolphin_35.xml
# Skipping file: jellyfish_113.jpg
# Skipping file: dolphin_48.xml
# starfish_11.txt
# Processing complete for file: starfish_11.txt
# starfish_59.txt
# Processing complete for file: starfish_59.txt
# Skipping file: jellyfish_103.jpg
# Skipping file: turtle_22.jpg
# turtle_7.txt
# Processing complete for file: turtle_7.txt
# Skipping file: fish_19.xml
# Skipping file: dolphin_54.jpg
# fish_102.txt
# Processing complete for file: fish_102.txt
# dolphin_46.txt
# Processing complete for file: dolphin_46.txt
# dolphin_56.txt
# Processing complete for file: dolphin_56.txt
# fish_105.txt
# Processing complete for file: fish_105.txt
# fish_119.txt
# Processing complete for file: fish_119.txt
# Skipping file: dolphin_28.xml
# Skipping file: starfish_11.xml
# Skipping file: dolphin_57.jpg
# jellyfish_60.txt
# Processing complete for file: jellyfish_60.txt
# Skipping file: dolphin_9.jpg
# Skipping file: jellyfish_60.xml
# Skipping file: fish_38.xml
# Skipping file: fish_40.xml
# Skipping file: fish_116.xml
# Skipping file: starfish_41.xml
# Skipping file: fish_43.jpg
# jellyfish_18.txt
# Processing complete for file: jellyfish_18.txt
# Skipping file: starfish_54.xml
# Skipping file: dolphin_44.xml
# Skipping file: starfish_111.jpg
# Skipping file: turtle_22.xml
# starfish_80.txt
# Processing complete for file: starfish_80.txt
# swordfish_61.txt
# Processing complete for file: swordfish_61.txt
# Skipping file: dolphin_7.jpg
# Skipping file: jellyfish_47.xml
# turtle_104.txt
# Processing complete for file: turtle_104.txt
# Skipping file: jellyfish_44.xml
# Skipping file: dolphin_100.xml
# Skipping file: starfish_59.xml
# Skipping file: jellyfish_46.jpg
# jellyfish_125.txt
# Processing complete for file: jellyfish_125.txt
# Skipping file: jellyfish_22.xml
# Skipping file: fish_34.jpg
# Skipping file: dolphin_107.jpg
# Skipping file: fish_39.xml
# Skipping file: turtle_102.xml
# Skipping file: starfish_22.jpg
# Skipping file: dolphin_26.jpg
# Skipping file: starfish_1.jpg
# dolphin_51.txt
# Processing complete for file: dolphin_51.txt
# Skipping file: jellyfish_63.jpg
# Skipping file: dolphin_101.jpg
# Skipping file: starfish_125.jpg
# Skipping file: swordfish_66.xml
# Skipping file: jellyfish_102.jpg
# turtle_108.txt
# Processing complete for file: turtle_108.txt
# Skipping file: dolphin_105.xml
# Skipping file: jellyfish_125.xml
# Skipping file: dolphin_0.jpg
# Skipping file: dolphin_1.jpg
# Skipping file: turtle_106.xml
# Skipping file: turtle_107.xml
# fish_111.txt
# Processing complete for file: fish_111.txt
# Skipping file: dolphin_103.jpg
# Skipping file: swordfish_85.jpg
# Skipping file: fish_13.jpg
# Skipping file: fish_72.jpg
# Skipping file: jellyfish_13.xml
# Skipping file: swordfish_73.jpg
# jellyfish_0.txt
# Processing complete for file: jellyfish_0.txt
# jellyfish_118.txt
# Processing complete for file: jellyfish_118.txt
# Skipping file: swordfish_0.jpg
# jellyfish_100.txt
# Processing complete for file: jellyfish_100.txt
# Skipping file: turtle_13.xml
# Skipping file: fish_6.jpg
# dolphin_28.txt
# Processing complete for file: dolphin_28.txt
# Skipping file: dolphin_66.xml
# Skipping file: fish_94.xml
# Skipping file: fish_34.xml
# Skipping file: jellyfish_15.jpg
# Skipping file: jellyfish_123.xml
# Skipping file: jellyfish_17.xml
# Skipping file: turtle_33.xml
# Skipping file: dolphin_3.xml
# Skipping file: dolphin_0.xml
# Skipping file: turtle_108.xml
# dolphin_69.txt
# Processing complete for file: dolphin_69.txt
# Skipping file: dolphin_7.xml
# dolphin_100.txt
# Processing complete for file: dolphin_100.txt
# Skipping file: swordfish_73.xml
# fish_1.txt
# Processing complete for file: fish_1.txt
# Skipping file: fish_38.jpg
# Skipping file: fish_117.jpg
# Skipping file: fish_75.xml
# turtle_1.txt
# Processing complete for file: turtle_1.txt
# swordfish_107.txt
# Processing complete for file: swordfish_107.txt
# Skipping file: dolphin_92.jpg
# Skipping file: starfish_100.jpg
# starfish_8.txt
# Processing complete for file: starfish_8.txt
# Skipping file: dolphin_106.xml
# turtle_105.txt
# Processing complete for file: turtle_105.txt
# Skipping file: jellyfish_27.jpg
# fish_118.txt
# Processing complete for file: fish_118.txt
# starfish_54.txt
# Processing complete for file: starfish_54.txt
# turtle_106.txt
# Processing complete for file: turtle_106.txt
# jellyfish_120.txt
# Processing complete for file: jellyfish_120.txt
# Skipping file: turtle_1.xml
# Skipping file: starfish_109.jpg
# starfish_110.txt
# Processing complete for file: starfish_110.txt
# jellyfish_22.txt
# Processing complete for file: jellyfish_22.txt
# turtle_17.txt
# Processing complete for file: turtle_17.txt
# dolphin_35.txt
# Processing complete for file: dolphin_35.txt
# Skipping file: dolphin_105.jpg
# Skipping file: jellyfish_18.jpg
# turtle_62.txt
# Processing complete for file: turtle_62.txt
# Skipping file: dolphin_53.jpg
# Skipping file: swordfish_107.xml
# Skipping file: starfish_0.jpg
# fish_6.txt
# Processing complete for file: fish_6.txt
# Skipping file: jellyfish_112.xml
# Skipping file: turtle_7.jpg
# Skipping file: starfish_11.jpg
# jellyfish_102.txt
# Processing complete for file: jellyfish_102.txt
# jellyfish_104.txt
# Processing complete for file: jellyfish_104.txt
# Skipping file: swordfish_28.xml
# Skipping file: dolphin_11.jpg
# dolphin_103.txt
# Processing complete for file: dolphin_103.txt
# dolphin_61.txt
# Processing complete for file: dolphin_61.txt
# Skipping file: fish_12.xml
# Skipping file: fish_21.jpg
# fish_21.txt
# Processing complete for file: fish_21.txt
# Skipping file: jellyfish_5.jpg
# starfish_125.txt
# Processing complete for file: starfish_125.txt
# Skipping file: dolphin_38.jpg
# Skipping file: jellyfish_12.jpg
# Skipping file: turtle_58.xml
# dolphin_108.txt
# Processing complete for file: dolphin_108.txt
# Skipping file: turtle_78.jpg
# Skipping file: dolphin_45.xml
# Skipping file: dolphin_69.jpg
# fish_26.txt
# Processing complete for file: fish_26.txt
# Skipping file: dolphin_5.jpg
# jellyfish_119.txt
# Processing complete for file: jellyfish_119.txt
# Skipping file: fish_32.jpg
# Skipping file: swordfish_106.xml
# Skipping file: turtle_7.xml
# Skipping file: jellyfish_100.xml
# Skipping file: jellyfish_12.xml
# Skipping file: jellyfish_32.xml
# Skipping file: jellyfish_15.xml
# Skipping file: jellyfish_18.xml
# Skipping file: jellyfish_102.xml
# starfish_121.txt
# Processing complete for file: starfish_121.txt
# swordfish_73.txt
# Processing complete for file: swordfish_73.txt
# dolphin_54.txt
# Processing complete for file: dolphin_54.txt
# starfish_111.txt
# Processing complete for file: starfish_111.txt
# Skipping file: jellyfish_17.jpg
# fish_60.txt
# Processing complete for file: fish_60.txt
# Skipping file: jellyfish_118.jpg
# Skipping file: dolphin_63.jpg
# Skipping file: turtle_104.jpg
# Skipping file: fish_1.jpg
# Skipping file: fish_61.xml
# Skipping file: dolphin_26.xml
# jellyfish_103.txt
# Processing complete for file: jellyfish_103.txt
# Skipping file: swordfish_42.xml
# Skipping file: starfish_13.xml
# Skipping file: swordfish_101.jpg
# Skipping file: starfish_58.jpg
# swordfish_66.txt
# Processing complete for file: swordfish_66.txt
# dolphin_25.txt
# Processing complete for file: dolphin_25.txt
# Skipping file: dolphin_17.jpg
# dolphin_107.txt
# Processing complete for file: dolphin_107.txt
# Skipping file: dolphin_25.jpg
# starfish_69.txt
# Processing complete for file: starfish_69.txt
# Skipping file: dolphin_100.jpg
# turtle_58.txt
# Processing complete for file: turtle_58.txt
# swordfish_56.txt
# Processing complete for file: swordfish_56.txt
# starfish_41.txt
# Processing complete for file: starfish_41.txt
# swordfish_106.txt
# Processing complete for file: swordfish_106.txt
# Skipping file: jellyfish_1.jpg
# Skipping file: dolphin_68.jpg
# fish_10.txt
# Processing complete for file: fish_10.txt
# Skipping file: swordfish_63.xml
# swordfish_1.txt
# Processing complete for file: swordfish_1.txt
# Skipping file: fish_61.jpg
# turtle_42.txt
# Processing complete for file: turtle_42.txt
# Skipping file: turtle_12.xml
# Skipping file: jellyfish_46.xml
# fish_61.txt
# Processing complete for file: fish_61.txt
# swordfish_0.txt
# Processing complete for file: swordfish_0.txt
# Skipping file: jellyfish_11.xml
# Skipping file: jellyfish_10.jpg
# Skipping file: swordfish_52.xml
# Skipping file: fish_51.jpg
# Skipping file: dolphin_58.jpg
# Skipping file: fish_26.jpg
# Skipping file: dolphin_52.jpg
# jellyfish_44.txt
# Processing complete for file: jellyfish_44.txt
# Skipping file: dolphin_68.xml
# Skipping file: swordfish_20.jpg
# swordfish_52.txt
# Processing complete for file: swordfish_52.txt
# Skipping file: turtle_13.jpg
# turtle_39.txt
# Processing complete for file: turtle_39.txt
# Skipping file: starfish_110.xml
# dolphin_59.txt
# Processing complete for file: dolphin_59.txt
# dolphin_48.txt
# Processing complete for file: dolphin_48.txt
# Skipping file: swordfish_85.xml
# starfish_103.txt
# Processing complete for file: starfish_103.txt
# Skipping file: swordfish_91.xml
# Skipping file: dolphin_61.jpg
# Skipping file: fish_31.xml
# Skipping file: jellyfish_104.jpg
# Skipping file: dolphin_15.xml
# Skipping file: turtle_25.jpg
# Skipping file: jellyfish_63.xml
# Skipping file: dolphin_5.xml
# Skipping file: jellyfish_47.jpg
# Skipping file: jellyfish_3.xml
# Skipping file: jellyfish_125.jpg
# Skipping file: jellyfish_5.xml
# Skipping file: dolphin_40.jpg
# turtle_103.txt
# Processing complete for file: turtle_103.txt
# fish_114.txt
# Processing complete for file: fish_114.txt
# Skipping file: turtle_62.jpg
# dolphin_7.txt
# Processing complete for file: dolphin_7.txt
# dolphin_2.txt
# Processing complete for file: dolphin_2.txt
# Skipping file: swordfish_20.xml
# Skipping file: swordfish_11.jpg
# Skipping file: dolphin_9.xml
# Skipping file: swordfish_106.jpg
# Skipping file: dolphin_35.jpg
# Skipping file: jellyfish_120.xml
# Skipping file: starfish_100.xml
# Skipping file: dolphin_4.xml
# Skipping file: turtle_30.xml
# fish_72.txt
# Processing complete for file: fish_72.txt
# dolphin_99.txt
# Processing complete for file: dolphin_99.txt
# Skipping file: turtle_102.jpg
# jellyfish_13.txt
# Processing complete for file: jellyfish_13.txt
# dolphin_23.txt
# Processing complete for file: dolphin_23.txt
# swordfish_11.txt
# Processing complete for file: swordfish_11.txt
# Skipping file: jellyfish_22.jpg
# Skipping file: jellyfish_9.xml
# Skipping file: turtle_78.xml
# turtle_18.txt
# Processing complete for file: turtle_18.txt
# Skipping file: starfish_108.xml
# Skipping file: dolphin_39.xml
# Skipping file: fish_111.xml
# Skipping file: swordfish_91.jpg
# Skipping file: turtle_101.jpg
# Skipping file: jellyfish_108.jpg
# jellyfish_9.txt
# Processing complete for file: jellyfish_9.txt
# dolphin_67.txt
# Processing complete for file: dolphin_67.txt
# Skipping file: fish_114.jpg
# Skipping file: swordfish_101.xml
# turtle_30.txt
# Processing complete for file: turtle_30.txt
# jellyfish_63.txt
# Processing complete for file: jellyfish_63.txt
# Skipping file: dolphin_104.jpg
# fish_12.txt
# Processing complete for file: fish_12.txt
# Skipping file: dolphin_24.xml
# Skipping file: jellyfish_124.xml
# fish_116.txt
# Processing complete for file: fish_116.txt
# Skipping file: dolphin_48.jpg
# starfish_119.txt
# Processing complete for file: starfish_119.txt
# fish_39.txt
# Processing complete for file: fish_39.txt
# starfish_60.txt
# Processing complete for file: starfish_60.txt
# Skipping file: turtle_104.xml
# Skipping file: dolphin_102.xml
# Skipping file: swordfish_56.xml
# Skipping file: fish_72.xml
# Skipping file: turtle_62.xml
# Skipping file: jellyfish_73.jpg
# turtle_100.txt
# Processing complete for file: turtle_100.txt
# turtle_78.txt
# Processing complete for file: turtle_78.txt
# Skipping file: fish_27.xml
# Skipping file: dolphin_45.jpg
# Skipping file: dolphin_51.xml
# Skipping file: dolphin_103.xml
# jellyfish_11.txt
# Processing complete for file: jellyfish_11.txt
# Skipping file: fish_10.jpg
# fish_38.txt
# Processing complete for file: fish_38.txt
# Skipping file: swordfish_109.jpg
# Skipping file: dolphin_1.xml
# turtle_10.txt
# Processing complete for file: turtle_10.txt
# Skipping file: jellyfish_3.jpg
# fish_94.txt
# Processing complete for file: fish_94.txt
# starfish_74.txt
# Processing complete for file: starfish_74.txt
# Skipping file: dolphin_108.xml
# Skipping file: fish_1.xml
# starfish_55.txt
# Processing complete for file: starfish_55.txt
# Skipping file: dolphin_62.xml
# dolphin_26.txt
# Processing complete for file: dolphin_26.txt
# fish_19.txt
# Processing complete for file: fish_19.txt
# Skipping file: dolphin_50.jpg
# Skipping file: jellyfish_73.xml
# Skipping file: starfish_93.jpg
# Skipping file: fish_26.xml
# Skipping file: dolphin_104.xml
# Skipping file: dolphin_20.xml
# Skipping file: starfish_110.jpg
# Skipping file: starfish_55.xml
# starfish_13.txt
# Processing complete for file: starfish_13.txt
# fish_50.txt
# Processing complete for file: fish_50.txt
# Skipping file: turtle_101.xml
# Skipping file: turtle_30.jpg
# Skipping file: jellyfish_119.xml
# Skipping file: fish_60.jpg
# starfish_118.txt
# Processing complete for file: starfish_118.txt
# Skipping file: dolphin_39.jpg
# Skipping file: jellyfish_1.xml
# jellyfish_3.txt
# Processing complete for file: jellyfish_3.txt
# Skipping file: jellyfish_118.xml

# %%
import os
os.getcwd()
# Out:
# '/home/dgu/faster-rcnn.pytorch/data'

# %%
# CUDA_VISIBLE_DEVICES=0 python trainval_net.py --dataset pascal_voc --net res101 --bs 4 --lr 4e-3 --lr_decay_step 8 --cuda

# %%
# python demo.py --net res101 --checksession 1 --checkepoch 20 --checkpoint 139 --cuda --load_dir models
