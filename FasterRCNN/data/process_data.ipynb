# %%
ls
# Out:
# pretrained_model/   train/  VOCdevkit/               yolo_voc_converter.ipynb
# process_data.ipynb  val/    VOCtest_06-Nov-2007.tar

# %%
# cd ..
# Out:
# F:\顾笛\Detection\darknet\build\darknet\x64

# %%
# import glob

# # path = 'data/'

# def generate_train_and_val(image_path, txt_file):
#     with open(txt_file, 'w') as tf:
#         for jpg_file in glob.glob(image_path + '*.jpg'):
#             tf.write(jpg_file + '\n')
#             print(jpg_file)

# generate_train_and_val('data/train/', 'data/train.txt')
# generate_train_and_val('data/val/', 'data/val.txt')
# Out:
# data/train\dolphin_0.jpg
# data/train\dolphin_1.jpg
# data/train\dolphin_10.jpg
# data/train\dolphin_100.jpg
# data/train\dolphin_101.jpg
# data/train\dolphin_102.jpg
# data/train\dolphin_103.jpg
# data/train\dolphin_104.jpg
# data/train\dolphin_105.jpg
# data/train\dolphin_106.jpg
# data/train\dolphin_107.jpg
# data/train\dolphin_108.jpg
# data/train\dolphin_109.jpg
# data/train\dolphin_11.jpg
# data/train\dolphin_12.jpg
# data/train\dolphin_14.jpg
# data/train\dolphin_15.jpg
# data/train\dolphin_17.jpg
# data/train\dolphin_19.jpg
# data/train\dolphin_2.jpg
# data/train\dolphin_20.jpg
# data/train\dolphin_23.jpg
# data/train\dolphin_24.jpg
# data/train\dolphin_25.jpg
# data/train\dolphin_26.jpg
# data/train\dolphin_27.jpg
# data/train\dolphin_28.jpg
# data/train\dolphin_29.jpg
# data/train\dolphin_3.jpg
# data/train\dolphin_32.jpg
# data/train\dolphin_34.jpg
# data/train\dolphin_35.jpg
# data/train\dolphin_38.jpg
# data/train\dolphin_39.jpg
# data/train\dolphin_4.jpg
# ...

# %%
import os,glob
def generate_train_and_val(image_path, txt_file):
    with open(txt_file, 'w') as tf:
        for filename in os.listdir(image_path):
            if filename.endswith('xml'):
                file_prefix = filename.split(".xml")[0]
                tf.write(file_prefix + '\n')
                print(file_prefix)
                
generate_train_and_val('train/', 'train.txt')
generate_train_and_val('val/', 'val.txt')
# Out:
# dolphin_53
# dolphin_2
# fish_119
# turtle_25
# fish_21
# dolphin_92
# swordfish_1
# dolphin_23
# swordfish_0
# fish_6
# turtle_105
# fish_43
# dolphin_38
# fish_118
# turtle_18
# dolphin_58
# dolphin_67
# starfish_125
# dolphin_32
# starfish_22
# starfish_119
# starfish_58
# starfish_80
# fish_114
# dolphin_40
# fish_60
# starfish_74
# starfish_8
# dolphin_59
# dolphin_70
# swordfish_11
# dolphin_61
# fish_2
# dolphin_101
# dolphin_54
# jellyfish_104
# dolphin_25
# dolphin_99
# fish_59
# starfish_69
# turtle_17
# dolphin_57
# turtle_103
# jellyfish_27
# swordfish_32
# jellyfish_0
# starfish_109
# dolphin_10
# fish_32
# fish_117
# swordfish_61
# dolphin_12
# starfish_103
# dolphin_63
# starfish_93
# dolphin_107
# dolphin_17
# starfish_107
# jellyfish_10
# dolphin_29
# fish_105
# dolphin_46
# turtle_39
# fish_110
# dolphin_52
# jellyfish_45
# jellyfish_113
# starfish_60
# jellyfish_122
# starfish_121
# starfish_48
# starfish_0
# fish_102
# fish_10
# turtle_100
# dolphin_56
# ...
